# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib 

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt

#workload is defined as the total workload / number of threads. 
#each thread executes 1e5 increments on a shared variable. and their 
# 4 CPUs, 16 cores.
# Sample data
x_values = [1,2,4,8,16,32]         # X-axis values
y_values = [399201, 1780649, 3739299, 6390277, 11269382, 19076281]        # Y-axis values

x_values2 = [1,2,4,8,16,32]
y_values2 = [1755874, 6659417, 13304627, 19451783, 42983680, 74926050]

# Create the plot
plt.figure(figsize=(8, 6))         # Set the figure size (optional)
plt.plot(x_values, y_values, marker='o', linestyle='-', color='b', label='Atomic')
plt.plot(x_values2, y_values2, marker='s', linestyle='--', color='r', label='Mutex')

# Add labels and title
plt.xlabel('X-axis Label')          # Label for the X-axis
plt.ylabel('Y-axis Label')          # Label for the Y-axis
plt.title('Atomic vs Mutexes, nanoseconds')       # Title of the graph

# Add grid and legend
plt.grid(True)                      # Show grid lines
plt.legend()                        # Display the legend

# Display the plot
plt.show()
